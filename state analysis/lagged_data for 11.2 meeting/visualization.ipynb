# %%
import pandas as pd
import re

# %%
final_state1=pd.read_csv('final_all.csv')
import matplotlib.pyplot as plt
# %matplotlib inline
final_state1=final_state.loc[~final_state['state_x'].isin(['New York','California','Florida','Texas']),:]

# %%
final_state1.columns
# Out:
# Index(['state_x', 'Per capita personal income (dollars) ',
#        'Personal income (thousands of dollars)', 'Population (persons) ',
#        'Disposable personal income (thousands of dollars)',
#        'Per capita disposable personal income (dollars) ', 'Accommodation',
#        'Accommodation and food services',
#        'Administrative and support and waste management and remediation services',
#        'Administrative and support services',
#        ...
#        'GeoName', 'Compensation of employees',
#        'Gross domestic product (GDP) by state', 'Gross operating surplus',
#        'Per capita real GDP by state',
#        'Quantity indexes for real GDP by state', 'Real GDP by state',
#        'Subsidies', 'Taxes on production and imports',
#        'Taxes on production and imports less subsidies'],
#       dtype='object', length=308)

# %%
fig=plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
ax1.scatter('Gross domestic product (GDP) by state','net_change',data=final_state1,color='orange')
ax1.title.set_text('Gdp vs Net change')
ax1.title.set_fontsize(15)
ax1.set_xlabel('Gross domestic product')
ax1.set_ylabel('Net Change')

ax2.scatter('Personal income (thousands of dollars)','net_change',data=final_state1,color='orange')
ax2.title.set_text('Personal income vs Net change')
ax2.set_xlabel('personal income')
ax2.title.set_fontsize(15)


ax3.scatter('Taxes on production and imports','net_change',data=final_state1,color='orange')
ax3.title.set_text('tax vs net_changeing')
ax3.set_xlabel('tax')
ax3.set_ylabel('net change of establishments')
ax3.title.set_fontsize(15)

ax4.scatter('Subsidies','net_change',data=final_state1,color='orange')
ax4.title.set_text('subsidies vsc net change')
ax4.set_xlabel('subsides')
ax4.title.set_fontsize(15)

# %%
fig=plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
ax1.scatter('Gross domestic product (GDP) by state','total_expand',data=final_state1,color='orange')
ax1.title.set_text('Gdp vs Expanding Number')
ax1.title.set_fontsize(15)
ax1.set_xlabel('Gross domestic product')
ax1.set_ylabel('total expanding number of establishments')
ax2.scatter('Personal income (thousands of dollars)','total_expand',data=final_state1,color='orange')
ax2.title.set_text('Personal Income vs Expanding Number')
ax2.set_xlabel('personal income')
ax2.title.set_fontsize(15)

ax3.scatter('Taxes on production and imports','total_contract',data=final_state1,color='orange')
ax3.title.set_text('tax vs total_contracting')
ax3.set_xlabel('tax')
ax3.set_ylabel('total contracting number of establishments')
ax3.title.set_fontsize(15)

ax4.scatter('Subsidies','total_expand',data=final_state1,color='orange')
ax4.title.set_text('subsidies vsc Expanding Number')
ax4.set_xlabel('subsides')
ax4.title.set_fontsize(15)

# %%
'''
fig=plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
ax1.scatter('irp','net_change',data=final_state1,color='orange')
ax1.title.set_text('Implicit Regional Price Deflator vs Net Change of Establishments')
ax1.set_xlabel('irp')
ax1.set_ylabel('Net change of Establishments')
ax2.scatter('RPP','net_change',data=final_state1,color='orange')
ax2.title.set_text('Real Purchase Parity vs Net Change of Establishments')
ax2.set_xlabel('purchase parity')

ax3.scatter('irp','total_expand',data=final_state1,color='orange')
ax3.title.set_text('Implicit Regional Price Deflator vs Total Expanding Number of Establishments')
ax3.set_xlabel('irp')
ax3.set_ylabel('total expanding number of establishments')
ax4.scatter('RPP','total_expand',data=final_state1,color='orange')
ax4.title.set_text('Real Purchase Parity vs Total Expanding Number of Establishments')
ax4.set_xlabel('purchase parity')
'''
# Out:
# "\nfig=plt.figure(figsize=(15,15))\nax1 = fig.add_subplot(221)\nax2 = fig.add_subplot(222)\nax3 = fig.add_subplot(223)\nax4 = fig.add_subplot(224)\nax1.scatter('irp','net_change',data=final_state1,color='orange')\nax1.title.set_text('Implicit Regional Price Deflator vs Net Change of Establishments')\nax1.set_xlabel('irp')\nax1.set_ylabel('Net change of Establishments')\nax2.scatter('RPP','net_change',data=final_state1,color='orange')\nax2.title.set_text('Real Purchase Parity vs Net Change of Establishments')\nax2.set_xlabel('purchase parity')\n\nax3.scatter('irp','total_expand',data=final_state1,color='orange')\nax3.title.set_text('Implicit Regional Price Deflator vs Total Expanding Number of Establishments')\nax3.set_xlabel('irp')\nax3.set_ylabel('total expanding number of establishments')\nax4.scatter('RPP','total_expand',data=final_state1,color='orange')\nax4.title.set_text('Real Purchase Parity vs Total Expanding Number of Establishments')\nax4.set_xlabel('purchase parity')\n"

# %%
#final_state1['total_grad']=final_state1[['total_engi', 'total_science']].sum(axis=1)
#final_state1['total_visa']=final_state1[['temporary_visa_engi','temporary_visa_science']].sum(axis=1)

# %%
'''
final_state1.columns
heat_map_columns=['total_engi', 'total_science',
        'land_area', 'water_area',
       'total_employed', 'member of unions', 
       'represented by unions', 'irp', 'RPP', 'gdp',
       'personal income', 'person consumption expenditure']
       '''
# Out:
# "\nfinal_state1.columns\nheat_map_columns=['total_engi', 'total_science',\n        'land_area', 'water_area',\n       'total_employed', 'member of unions', \n       'represented by unions', 'irp', 'RPP', 'gdp',\n       'personal income', 'person consumption expenditure']\n       "

# %%
#heat_map_df.corr()
# Out:
#                                 total_engi  total_science  land_area  \
# total_engi                        1.000000       0.788831  -0.175570
# total_science                     0.788831       1.000000  -0.176260
# land_area                        -0.175570      -0.176260   1.000000
# water_area                        0.028180      -0.012626   0.825734
# total_employed                    0.905803       0.609872  -0.177842
# member of unions                  0.830483       0.583986  -0.146758
# represented by unions             0.845009       0.583864  -0.149212
# irp                               0.086252       0.269802  -0.025987
# RPP                               0.086477       0.269825  -0.026151
# gdp                               0.914401       0.672762  -0.186095
# personal income                   0.912003       0.669575  -0.187961
# person consumption expenditure    0.921641       0.666358  -0.180153
#
# ...

# %%
heat_map_df['represented by unions']=heat_map_df['represented by unions'].astype(int)

# %%
'''
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(heat_map_df)
hd=scaler.transform(heat_map_df)
final_heat_df=pd.DataFrame(hd, columns = heat_map_df.columns)
'''

# %%
'''
import seaborn as sns
fig=plt.figure(figsize=(10,10))
ax = sns.heatmap(heat_map_df.corr())
plt.title('Heat Map for Correlation',fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
'''
# Out:
# (array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#           9.5,  10.5,  11.5]), <a list of 12 Text yticklabel objects>)

# %%
'''
pair_columns=['total_engi',
        'land_area',
       'total_employed', 'member of unions', 
        'RPP', 'gdp',
       'personal income', 'person consumption expenditure','total_expand']
pair_df=final_state1.loc[:,pair_columns]
fig=plt.figure(figsize=(10,10))
ax = sns.pairplot(pair_df)
'''
# Out:
# "\npair_columns=['total_engi',\n        'land_area',\n       'total_employed', 'member of unions', \n        'RPP', 'gdp',\n       'personal income', 'person consumption expenditure','total_expand']\npair_df=final_state1.loc[:,pair_columns]\nfig=plt.figure(figsize=(10,10))\nax = sns.pairplot(pair_df)\n"
